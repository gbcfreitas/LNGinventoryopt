# %%
from models_otimizador import otimizador
import pandas as pd
import json
import pulp

import logging

# Configurar o logging para mostrar mensagens INFO
# permitir uso de acentos no formato
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler()  # Para mostrar no output do notebook
    ],
    style='%'
)

# Ou de forma mais simples:
logging.getLogger().setLevel(logging.INFO)


# %load_ext autoreload
# %reload_ext autoreload

# %autoreload 2

# %% [markdown]
# # Resumo dos resultados

# %%
# Importar resultados das runs de saidas/saidas.json
with open('saidas/saidas.json', 'r') as f:
    resultados = json.load(f)
    
# Transformar em DataFrame para melhor visualização em que cada run é uma linha
df_resultados = pd.DataFrame(resultados).T
# Transformar as keys dos valores da coluna options em novas colunas
options_df = df_resultados['options'].apply(pd.Series)
# substituir coluna options pelas colunas expandidas
df_resultados = pd.concat([df_resultados.drop(columns=['options']), options_df], axis=1)
# fazer o mesmo com os valores da coluna custos
custos_df = df_resultados['custos'].apply(pd.Series)
df_resultados = pd.concat([df_resultados.drop(columns=['custos']), custos_df], axis=1)
df_resultados = df_resultados.sort_values(by='RUN')
# Formatar os valores numéricos com separador de milhar
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_resultados
# Out:
#                       status solution_time  objective_value  NOME  NO_BOG  \
# 1   Solução ótima encontrada          0.68 1,049,465,920.60  Cen1    True
# 2   Solução ótima encontrada          2.19 1,069,757,920.60  Cen1   False
# 3   Solução ótima encontrada          0.71 1,069,757,920.60  Cen1   False
# 4   Solução ótima encontrada         21.86 1,075,635,634.01  Cen1   False
# 5   Solução ótima encontrada          0.45 1,076,235,121.44  Cen1   False
# 6   Solução ótima encontrada          1.08 1,055,089,640.78  Cen1    True
# 7   Solução ótima encontrada          0.32 1,055,319,579.56  Cen1    True
# 8   Solução ótima encontrada          1.05 1,058,041,039.80  Cen1    True
# 9   Solução ótima encontrada          0.41 1,058,391,653.34  Cen1    True
# 10  Solução ótima encontrada          0.62 1,055,273,205.00  Cen1    True
# 11  Solução ótima encontrada          0.45 1,055,517,048.18  Cen1    True
# 12  Solução ótima encontrada         16.63 1,082,242,809.41  Cen1   False
# 13  Solução ótima encontrada          0.73 1,082,986,250.74  Cen1   False
# 14  Solução ótima encontrada         11.05 1,081,383,351.38  Cen1   False
# 15  Solução ótima encontrada          0.38 1,082,100,889.41  Cen1   False
# 16  Solução ótima encontrada         10.24 1,075,635,634.01  Cen1   False
# 20  Solução ótima encontrada          2.22     5,063,283.15  Cen1    True
# 21  Solução ótima encontrada      3,608.92 2,123,527,303.28  Cen1    True
#
#     BOG_CTE  BOG_VAR  LOCK_POLICY  CAPCOST  CAPCOST_VALUE  ...  \
# 1     False    False        False    False            NaN  ...
# 2      True    False        False    False            NaN  ...
# 3      True    False         True    False            NaN  ...
# 4     False     True        False    False            NaN  ...
# 5     False     True         True    False            NaN  ...
# 6     False    False        False     True            NaN  ...
# 7     False    False         True     True            NaN  ...
# 8     False    False        False     True            NaN  ...
# 9     False    False         True     True            NaN  ...
# 10    False    False        False     True            NaN  ...
# 11    False    False         True     True            NaN  ...
# 12    False     True        False     True            NaN  ...
# 13    False     True         True     True            NaN  ...
# 14    False     True        False     True            NaN  ...
# 15    False     True         True     True            NaN  ...
# 16    False     True        False    False            NaN  ...
# 20    False    False        False    False            NaN  ...
# 21    False    False        False    False            NaN  ...
#
#    CAPCOST_version  TIMELIMIT  RUN     custo_fixo       custo_spot  \
# 1               V2      10800    1 118,374,400.00   270,804,480.60
# 2               V2      10800    2 118,374,400.00   291,096,480.60
# 3               V2      10800    3 118,374,400.00   291,096,480.60
# 4               V2      10800    4 118,374,400.00   296,974,194.01
# 5               V2      10800    5 118,374,400.00   297,573,681.44
# 6               V1      10800    6 118,374,400.00   270,804,480.60
# 7               V1      10800    7 118,374,400.00   270,804,480.60
# 8               V1      10800    8 118,374,400.00   270,804,480.60
# 9               V1      10800    9 118,374,400.00   270,804,480.60
# 10              V2      10800   10 118,374,400.00   270,804,480.60
# 11              V2      10800   11 118,374,400.00   270,804,480.60
# 12              V2      10800   12 118,374,400.00   296,974,194.01
# 13              V2      10800   13 118,374,400.00   297,573,681.44
# 14              V1      10800   14 118,374,400.00   296,974,194.01
# 15              V1      10800   15 118,374,400.00   297,573,681.44
# 16             NaN      10800   16 118,374,400.00   296,974,194.01
# 20              V2      10800   20 443,904,000.00 1,126,374,480.60
# 21              V2      10800   21 162,764,800.00 1,185,388,719.21
#
#         custo_lcp  custo_demurrage      custo_top  custo_cap      custo_total
# 1  618,856,000.00    41,431,040.00           0.00       0.00 1,049,465,920.60
# 2  618,856,000.00    41,431,040.00           0.00       0.00 1,069,757,920.60
# 3  618,856,000.00    41,431,040.00           0.00       0.00 1,069,757,920.60
# 4  618,856,000.00    41,431,040.00           0.00       0.00 1,075,635,634.01
# 5  618,856,000.00    41,431,040.00           0.00       0.00 1,076,235,121.44
# 6  618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 7  618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 8  618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 9  618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 10 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 11 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 12 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 13 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 14 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 15 618,856,000.00    41,431,040.00           0.00        NaN              NaN
# 16 618,856,000.00    41,431,040.00           0.00       0.00 1,075,635,634.01
# 20           0.00             0.00 754,358,242.25       0.00 2,324,636,722.85
# 21           0.00             0.00 754,358,242.25       0.00 2,102,511,761.46
#
# [18 rows x 23 columns]

# %%
df_resultados.to_excel('saidas/resultados_otimizacao.xlsx', index_label='run_id')
